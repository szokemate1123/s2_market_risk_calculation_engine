# %%
from market_risk_calculator import *

input_file = '../template/market_risk_template.xlsx'

asset_list_dfs, ul_list_dfs, calc_dfs = calculate_everything(input_file)

# %%
calc_dfs[0]
# Out:
#     portfolio_group      portfolio_id analysis_date  \
# 0            213-KV      HU0000403118    2024-09-30
# 1            213-LV      HU0000402748    2024-09-30
# 2            213-LV      HU0000402748    2024-09-30
# 3            213-LV      HU0000403340    2024-09-30
# 4            213-LV      HU0000403118    2024-09-30
# ..              ...               ...           ...
# 909          213-SV  213S-RB99007/EUR    2024-09-30
# 910          213-SV  213S-RB99043/HUF    2024-09-30
# 911          213-SV  213S-RB99063/HUF    2024-09-30
# 912          213-SV  213S-RB99044/EUR    2024-09-30
# 913          213-SV  213S-RBIAT10/EUR    2024-09-30
#
#                         security_name country rating cic_of_instrument  \
# 0                      HGB 3 10/27/27      HU    BBB              HU11
# 1                  HGB 5 1/2 06/24/25      HU    BBB              HU11
# 2                  HGB 5 1/2 06/24/25      HU    BBB              HU11
# 3                  HGB 2 3/4 12/22/26      HU    BBB              HU11
# 4                      HGB 3 10/27/27      HU    BBB              HU11
# ..                                ...     ...    ...               ...
# 909               Raiffeisen Bank zrt      HU    nan              XT72
# 910               Raiffeisen Bank zrt      HU    nan              XT72
# 911               Raiffeisen Bank zrt      HU    nan              XT72
# 912               Raiffeisen Bank zrt      HU    nan              XT72
# 913  Raiffeisen Bank International AG      HU    nan              XT72
#
#                    asset_allocation currency exp_maturity_date  ...  \
# 0               100. Staatsanleihen      HUF        2027-10-27  ...
# 1               100. Staatsanleihen      HUF        2025-06-24  ...
# 2               100. Staatsanleihen      HUF        2025-06-24  ...
# 3               100. Staatsanleihen      HUF        2026-12-22  ...
# 4               100. Staatsanleihen      HUF        2027-10-27  ...
# ..                              ...      ...               ...  ...
# 909  995. Cash and cash equivalents      EUR               NaT  ...
# 910  995. Cash and cash equivalents      HUF               NaT  ...
# 911  995. Cash and cash equivalents      HUF               NaT  ...
# 912  995. Cash and cash equivalents      EUR               NaT  ...
# 913  995. Cash and cash equivalents      EUR               NaT  ...
#
#      id_of_underlying  name_of_underlying  qc_of_underlying valuation_weight  \
# 0                 NaN                 NaN               HUF              1.0
# 1                 NaN                 NaN               HUF              1.0
# 2                 NaN                 NaN               HUF              1.0
# 3                 NaN                 NaN               HUF              1.0
# 4                 NaN                 NaN               HUF              1.0
# ..                ...                 ...               ...              ...
# 909               NaN                 NaN               EUR              1.0
# 910               NaN                 NaN               HUF              1.0
# 911               NaN                 NaN               HUF              1.0
# 912               NaN                 NaN               EUR              1.0
# 913               NaN                 NaN               EUR              1.0
#
#      maturity_date cqs mod_dur_of_underlying  underlying_asset_category  \
# 0       2027-10-27   3                 2.739                        NaN
# 1       2025-06-24   3                 0.695                        NaN
# 2       2025-06-24   3                 0.695                        NaN
# 3       2026-12-22   3                 2.031                        NaN
# 4       2027-10-27   3                 2.739                        NaN
# ..             ...  ..                   ...                        ...
# 909            NaT   6                   NaN                        NaN
# 910            NaT   6                   NaN                        NaN
# 911            NaT   6                   NaN                        NaN
# 912            NaT   6                   NaN                        NaN
# 913            NaT   6                   NaN                        NaN
#
#     calculation_type         value
# 0                  1  1.242861e+09
# 1                  1  1.930660e+08
# 2                  1  1.219364e+08
# 3                  1  2.409785e+08
# 4                  1  2.198908e+08
# ..               ...           ...
# 909                7  6.850694e+06
# 910                7  2.313483e+06
# 911                7  2.687147e+07
# 912                7  1.438347e+07
# 913                7  2.437900e+09
#
# [914 rows x 28 columns]

# %%
calc_dfs[1]
# Out:
#        portfolio_group  portfolio_id analysis_date  \
# 0                HU_N5     HU_N5_HUF    2024-09-30
# 1                HU_N5  CZ0008472891    2024-09-30
# 2                HU_N5  CZ0008472891    2024-09-30
# 3                HU_N5  CZ0008472891    2024-09-30
# 4                HU_N5  CZ0008472891    2024-09-30
# ...                ...           ...           ...
# 323910          HU_U07  US4642874576    2024-09-30
# 323911          HU_U07  US4642874576    2024-09-30
# 323912          HU_U07  US4642874576    2024-09-30
# 323913          HU_U07  US4642874576    2024-09-30
# 323914          HU_U07  US4642874576    2024-09-30
#
#                          security_name country rating cic_of_instrument  \
# 0        HU ABSZOLUT HOZAMÚ ESZKÖZALAP      HU    nan              XT72
# 1       UNIQA SEL EM EQ SPECIALNI FOND      CZ    nan              XL41
# 2       UNIQA SEL EM EQ SPECIALNI FOND      CZ    nan              XL41
# 3       UNIQA SEL EM EQ SPECIALNI FOND      CZ    nan              XL41
# 4       UNIQA SEL EM EQ SPECIALNI FOND      CZ    nan              XL41
# ...                                ...     ...    ...               ...
# 323910    ISHARES 1-3 YEAR TREASURY BO      US    nan              US42
# 323911    ISHARES 1-3 YEAR TREASURY BO      US    nan              US42
# 323912    ISHARES 1-3 YEAR TREASURY BO      US    nan              US42
# 323913    ISHARES 1-3 YEAR TREASURY BO      US    nan              US42
# 323914    ISHARES 1-3 YEAR TREASURY BO      US    nan              US42
#
#                         asset_allocation currency exp_maturity_date  ...  \
# 0         995. Cash and cash equivalents      HUF               NaT  ...
# 1             640. Emma - Fond or linked      EUR               NaT  ...
# 2             640. Emma - Fond or linked      EUR               NaT  ...
# 3             640. Emma - Fond or linked      EUR               NaT  ...
# 4             640. Emma - Fond or linked      EUR               NaT  ...
# ...                                  ...      ...               ...  ...
# 323910  650. High Grade - Fond or linked      USD               NaT  ...
# 323911  650. High Grade - Fond or linked      USD               NaT  ...
# 323912  650. High Grade - Fond or linked      USD               NaT  ...
# 323913  650. High Grade - Fond or linked      USD               NaT  ...
# 323914  650. High Grade - Fond or linked      USD               NaT  ...
#
#         id_of_underlying         name_of_underlying  qc_of_underlying  \
# 0                    NaN                        NaN               HUF
# 1           AEA000201011  ABU DHABI COMMERCIAL BANK               AED
# 2           AEA000701010          WAHA CAPITAL PJSC               AED
# 3           AEA000801018     ABU DHABI ISLAMIC BANK               AED
# 4           AEA001001014      ABU DHABI AVIATION CO               AED
# ...                  ...                        ...               ...
# 323910      US91282CED92              TREASURY NOTE               USD
# 323911      US91282CDH16              TREASURY NOTE               USD
# 323912      US9128284F40              TREASURY NOTE               USD
# 323913      US912828G385              TREASURY NOTE               USD
# 323914         USD_CCASH                   USD CASH               USD
#
#        valuation_weight  maturity_date      cqs mod_dur_of_underlying  \
# 0          1.000000e+00            NaT        6                   NaN
# 1          4.179700e-04            NaT      NaN                   NaN
# 2          2.690000e-05            NaT      NaN                   NaN
# 3          2.710730e-04            NaT      NaN                   NaN
# 4          9.660000e-06            NaT      NaN                   NaN
# ...                 ...            ...      ...                   ...
# 323910     1.406940e-07     2025-03-15  10000.0               0.44911
# 323911     9.460570e-08     2024-11-15  10000.0               0.12214
# 323912     9.402410e-08     2025-03-31  10000.0               0.48961
# 323913     4.765630e-08     2024-11-15  10000.0               0.12213
# 323914    -1.244070e-04            NaT      NaN               0.00000
#
#         underlying_asset_category calculation_type         value
# 0                             NaN                7 -2.754796e+06
# 1                              3L               3L  2.400084e+04
# 2                              3L               3L  1.544662e+03
# 3                              3L               3L  1.556566e+04
# 4                              3L               3L  5.547004e+02
# ...                           ...              ...           ...
# 323910                          1               1X  7.284685e+00
# 323911                          1               1X  4.898381e+00
# 323912                          1               1X  4.868267e+00
# 323913                          1               1X  2.467491e+00
# 323914                          L                7 -6.441397e+03
#
# [323915 rows x 28 columns]
