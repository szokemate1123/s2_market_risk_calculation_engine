# %%
from market_risk_calculator import *

input_file = '../template/market_risk_template.xlsx'

asset_list_dfs, ul_list_dfs, calc_dfs = calculate_everything(input_file)
# Out:
# e:\régi gép\Régi gép\BME MSc\negyedik_felev\diplomamunka\code\market_risk\codes\base_functions.py:244: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: illegal_characters.sub('', x) if isinstance(x, str) else x)
# e:\régi gép\Régi gép\BME MSc\negyedik_felev\diplomamunka\code\market_risk\codes\base_functions.py:244: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: illegal_characters.sub('', x) if isinstance(x, str) else x)
# e:\régi gép\Régi gép\BME MSc\negyedik_felev\diplomamunka\code\market_risk\codes\data_validation.py:749: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
calc_dfs[0]
# Out:
#              portfolio_group portfolio_id analysis_date  \
# 0   MAIN_INSURANCE_PORTFOLIO     ASSET001    2025-03-31
# 1   MAIN_INSURANCE_PORTFOLIO     ASSET002    2025-03-31
# 2   MAIN_INSURANCE_PORTFOLIO     ASSET003    2025-03-31
# 3   MAIN_INSURANCE_PORTFOLIO     ASSET004    2025-03-31
# 4   MAIN_INSURANCE_PORTFOLIO     ASSET005    2025-03-31
# ..                       ...          ...           ...
# 88  MAIN_INSURANCE_PORTFOLIO     ASSET043    2025-03-31
# 89  MAIN_INSURANCE_PORTFOLIO     ASSET044    2025-03-31
# 90  MAIN_INSURANCE_PORTFOLIO     ASSET045    2025-03-31
# 91  MAIN_INSURANCE_PORTFOLIO     ASSET046    2025-03-31
# 92  MAIN_INSURANCE_PORTFOLIO     ASSET047    2025-03-31
#
#                              security_name country rating cic_of_instrument  \
# 0          Hungarian Gov. Bond PMÁP 2030/A      HU    2.0              HU1A
# 1          Hungarian Gov. Bond MÁP+ 2029/N      HU    2.0              HU1A
# ...

# %%
calc_dfs[1]
# Out:
#             portfolio_group portfolio_id analysis_date  \
# 0   UNIT_LINKED_LOOKTHROUGH   ULASSET001    2025-03-31
# 1   UNIT_LINKED_LOOKTHROUGH   ULASSET002    2025-03-31
# 2   UNIT_LINKED_LOOKTHROUGH   ULASSET003    2025-03-31
# 3   UNIT_LINKED_LOOKTHROUGH   ULASSET004    2025-03-31
# 4   UNIT_LINKED_LOOKTHROUGH   ULASSET005    2025-03-31
# ..                      ...          ...           ...
# 80  UNIT_LINKED_LOOKTHROUGH   ULASSET042    2025-03-31
# 81  UNIT_LINKED_LOOKTHROUGH   ULASSET043    2025-03-31
# 82  UNIT_LINKED_LOOKTHROUGH   ULASSET044    2025-03-31
# 83  UNIT_LINKED_LOOKTHROUGH   ULASSET045    2025-03-31
# 84  UNIT_LINKED_LOOKTHROUGH   ULASSET046    2025-03-31
#
#                                         security_name country rating  \
# 0                    Hungarian Gov. Bond PMĂP 2030/A      HU    2.0
# 1                    Hungarian Gov. Bond MĂP+ 2029/N      HU    2.0
# 2                     German Gov. Bond Bund 2035 1.5%      DE    0.0
# ...
